# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models
from torch.utils.data import DataLoader, WeightedRandomSampler, random_split
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import copy

# ------------------------ SETTINGS ------------------------
DATA_DIR = '/kaggle/input/x-ray-dataset-with-unk/xray-dataset-lung'
BATCH_SIZE = 32
NUM_EPOCHS = 50
PATIENCE = 8
NUM_CLASSES = 3  # cancer, normal, unknown
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ------------------------ TRANSFORMS ------------------------
train_transform = A.Compose([
    A.Resize(224, 224),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.2),
    A.RandomBrightnessContrast(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=20, p=0.5),
    A.CoarseDropout(p=0.5),
    A.Normalize(),
    ToTensorV2(),
])

val_test_transform = A.Compose([
    A.Resize(224, 224),
    A.Normalize(),
    ToTensorV2(),
])

# Custom Dataset
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset

class AlbumentationsDataset(Dataset):
    def __init__(self, dataset, transform):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, label = self.dataset[idx]
        img = np.array(img)
        img = self.transform(image=img)['image']
        return img, label

# ------------------------ DATASET & SAMPLER ------------------------
dataset = ImageFolder(DATA_DIR)
class_names = dataset.classes

train_len = int(0.6 * len(dataset))
val_len = int(0.2 * len(dataset))
test_len = len(dataset) - train_len - val_len
train_ds, val_ds, test_ds = random_split(dataset, [train_len, val_len, test_len])

train_ds = AlbumentationsDataset(train_ds, train_transform)
val_ds = AlbumentationsDataset(val_ds, val_test_transform)
test_ds = AlbumentationsDataset(test_ds, val_test_transform)

targets = [label for _, label in train_ds]
class_sample_counts = np.bincount(targets)
weights = 1. / class_sample_counts
sample_weights = [weights[t] for t in targets]
sampler = WeightedRandomSampler(sample_weights, len(sample_weights))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# ------------------------ MODEL ------------------------
model = models.resnet50(weights="IMAGENET1K_V1")
model.fc = nn.Linear(model.fc.in_features, NUM_CLASSES)
model = model.to(DEVICE)

# Freeze all layers first
for param in model.parameters():
    param.requires_grad = False

# Only last fc layer trainable
for param in model.fc.parameters():
    param.requires_grad = True

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=1e-3)

best_model = None
best_acc = 0
early_stop_counter = 0

# ------------------------ WARMUP: Train only FC layer ------------------------
print("🔵 Stage 1: Training FC Layer Only...")
for epoch in range(5):  # 5 epochs warmup
    model.train()
    train_loss, correct, total = 0.0, 0, 0
    for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/5 - Warmup"):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_acc = correct / total
    print(f"Warmup Epoch {epoch+1} -> Train Acc: {train_acc:.4f}")

# ------------------------ UNFREEZE & Fine-tune all layers ------------------------
print("\n🟢 Stage 2: Fine-tuning full model...")
for param in model.parameters():
    param.requires_grad = True

optimizer = optim.AdamW(model.parameters(), lr=2e-4, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, factor=0.5, verbose=True)

# ------------------------ FULL TRAINING ------------------------
for epoch in range(NUM_EPOCHS):
    model.train()
    train_loss, correct, total = 0.0, 0, 0
    for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS} - Training"):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_acc = correct / total

    # Validation
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, labels in tqdm(val_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS} - Validation"):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_acc = correct / total
    scheduler.step(val_acc)

    print(f"Epoch {epoch+1} -> Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    if val_acc > best_acc:
        best_acc = val_acc
        best_model = copy.deepcopy(model.state_dict())
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        if early_stop_counter >= PATIENCE:
            print("Early stopping triggered!")
            break

# Load best model
torch.save(best_model, "best_resnet50.pth")
model.load_state_dict(best_model)

print(f"\n🌟 Best Validation Accuracy: {best_acc:.4f}")

# ------------------------ TEST & EVALUATION ------------------------
model.eval()
all_preds, all_labels, all_probs = [], [], []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(DEVICE)
        outputs = model(inputs)
        probs = torch.softmax(outputs, 1)
        preds = torch.argmax(probs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
        all_probs.extend(probs.cpu().numpy())

# Confusion matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:\n", classification_report(all_labels, all_preds, target_names=class_names))

# Kappa Score
kappa = cohen_kappa_score(all_labels, all_preds)
print("Cohen's Kappa Score:", kappa)

# ROC Curve
all_labels_np = np.array(all_labels)
all_probs_np = np.array(all_probs)

for i in range(NUM_CLASSES):
    fpr, tpr, _ = roc_curve((all_labels_np == i).astype(int), all_probs_np[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")

plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (One-vs-Rest)")
plt.legend()
plt.grid()
plt.show()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 228MB/s]
# 🔵 Stage 1: Training FC Layer Only...
# Epoch 1/5 - Warmup: 100%|██████████| 51/51 [00:25<00:00,  2.01it/s]
# Warmup Epoch 1 -> Train Acc: 0.6749
# Epoch 2/5 - Warmup: 100%|██████████| 51/51 [00:23<00:00,  2.14it/s]
# Warmup Epoch 2 -> Train Acc: 0.7554
# Epoch 3/5 - Warmup: 100%|██████████| 51/51 [00:24<00:00,  2.10it/s]
# Warmup Epoch 3 -> Train Acc: 0.7808
# Epoch 4/5 - Warmup: 100%|██████████| 51/51 [00:24<00:00,  2.09it/s]
# Warmup Epoch 4 -> Train Acc: 0.7554
# Epoch 5/5 - Warmup: 100%|██████████| 51/51 [00:24<00:00,  2.09it/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#
50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.65it/s]
# Epoch 22/50 - Validation: 100%|██████████| 17/17 [00:08<00:00,  2.11it/s]
# Epoch 22 -> Train Acc: 0.9399 | Val Acc: 0.8346
# Epoch 23/50 - Training: 100%|██████████| 51/51 [00:31<00:00,  1.64it/s]
# Epoch 23/50 - Validation: 100%|██████████| 17/17 [00:08<00:00,  2.12it/s]
# Epoch 23 -> Train Acc: 0.9474 | Val Acc: 0.8680
# Epoch 24/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.68it/s]
# Epoch 24/50 - Validation: 100%|██████████| 17/17 [00:08<00:00,  2.10it/s]
# Epoch 24 -> Train Acc: 0.9362 | Val Acc: 0.8327
# Epoch 25/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.72it/s]
# Epoch 25/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.16it/s]
# Epoch 25 -> Train Acc: 0.9505 | Val Acc: 0.8662
# Epoch 26/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.69it/s]
# Epoch 26/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.17it/s]
# Epoch 26 -> Train Acc: 0.9542 | Val Acc: 0.8792
# Epoch 27/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.69it/s]
# Epoch 27/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.18it/s]
# Epoch 27 -> Train Acc: 0.9554 | Val Acc: 0.8903
# Epoch 28/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.71it/s]
# Epoch 28/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.16it/s]
# Epoch 28 -> Train Acc: 0.9529 | Val Acc: 0.8848
# Epoch 29/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.70it/s]
# Epoch 29/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.21it/s]
# Epoch 29 -> Train Acc: 0.9628 | Val Acc: 0.8903
# Epoch 30/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.72it/s]
# Epoch 30/50 - Validation: 100%|██████████| 17/17 [00:08<00:00,  2.12it/s]
# Epoch 30 -> Train Acc: 0.9554 | Val Acc: 0.8885
# Epoch 31/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.70it/s]
# Epoch 31/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 31 -> Train Acc: 0.9598 | Val Acc: 0.8866
# Epoch 32/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.68it/s]
# Epoch 32/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 32 -> Train Acc: 0.9653 | Val Acc: 0.8773
# Epoch 33/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.73it/s]
# Epoch 33/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 33 -> Train Acc: 0.9635 | Val Acc: 0.8885
# Epoch 34/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.69it/s]
# Epoch 34/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 34 -> Train Acc: 0.9697 | Val Acc: 0.8885
# Epoch 35/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.68it/s]
# Epoch 35/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 35 -> Train Acc: 0.9759 | Val Acc: 0.8922
# Epoch 36/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.73it/s]
# Epoch 36/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.18it/s]
# Epoch 36 -> Train Acc: 0.9752 | Val Acc: 0.8903
# Epoch 37/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.73it/s]
# Epoch 37/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.22it/s]
# Epoch 37 -> Train Acc: 0.9635 | Val Acc: 0.8829
# Epoch 38/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.71it/s]
# Epoch 38/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 38 -> Train Acc: 0.9703 | Val Acc: 0.8717
# Epoch 39/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.70it/s]
# Epoch 39/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.23it/s]
# Epoch 39 -> Train Acc: 0.9672 | Val Acc: 0.8717
# Epoch 40/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.72it/s]
# Epoch 40/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.21it/s]
# Epoch 40 -> Train Acc: 0.9721 | Val Acc: 0.8773
# Epoch 41/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.72it/s]
# Epoch 41/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.17it/s]
# Epoch 41 -> Train Acc: 0.9765 | Val Acc: 0.8848
# Epoch 42/50 - Training: 100%|██████████| 51/51 [00:30<00:00,  1.69it/s]
# Epoch 42/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.17it/s]
# Epoch 42 -> Train Acc: 0.9777 | Val Acc: 0.8848
# Epoch 43/50 - Training: 100%|██████████| 51/51 [00:29<00:00,  1.72it/s]
# Epoch 43/50 - Validation: 100%|██████████| 17/17 [00:07<00:00,  2.19it/s]
# Epoch 43 -> Train Acc: 0.9796 | Val Acc: 0.8848
# Early stopping triggered!
#
# 🌟 Best Validation Accuracy: 0.8922
# Classification Report:
#                              precision    recall  f1-score   support
#
#          Lung Cancer X-ray       0.82      0.68      0.74       150
#                     Normal       0.81      0.90      0.85       223
# unsplash-images-collection       1.00      1.00      1.00       167
#
#                   accuracy                           0.87       540
#                  macro avg       0.87      0.86      0.86       540
#               weighted avg       0.87      0.87      0.87       540
#
# Cohen's Kappa Score: 0.7978455843970959
